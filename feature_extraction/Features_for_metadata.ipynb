# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from pandas.core.common import SettingWithCopyWarning

warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

# %%
direc = "E:\\WS4PD_data"
os.chdir(direc)
# load data
demogra_data = pd.read_csv("Demographics_data.csv")
score_file_path = os.path.join(direc, 'Feature_extraction','score_by_device.pkl')
df_score = pd.read_pickle(score_file_path)
save_path = os.path.join(direc, "Feature_extraction")

# %%
# Manual correction
# The diagnosis year for subject #20 is 2006-2007, and we choose 2006 as the diagnosis year 
demogra_data.loc[20,'diagnosis_year'] = 2006

# %%
demogra_data.columns
# Out:
# Index(['ROW_ID', 'ROW_VERSION', 'subject_id', 'cohort', 'gender', 'birth_year',
#        'dominant_hand', 'upper_limb_length', 'upper_arm_length',
#        'lower_arm_length', 'lower_limb_length', 'thigh_length', 'shank_length',
#        'height', 'weight', 'visit_date', 'diagnosis_day', 'diagnosis_month',
#        'diagnosis_year', 'pd_most_affected_side', 'gait_impediments',
#        'posture_instability', 'tremor', 'bradykinesia', 'disrupted_sleep',
#        'freeze_of_gait', 'dyskinesia', 'rigidity', 'other_symptoms',
#        'last_levodopa_dose_timestamp', 'regular_medication', 'geneactive_num',
#        'pebble_num', 'geneactive_hand', 'pebble_hand', 'smartphone_location',
#        'recording_start', 'recording_end', 'timezone', 'updrs_time',
#        'updrs_score_p1', 'updrs_score_p2', 'updrs_score_p3', 'updrs_score_p4',
#        'h_and_y_score', 'updrs_second_visit_time',
#        'updrs_second_visit_score_p3'],
#       dtype='object')

# %%
# Get age and age diagnosis
visit_year  = 2015 # Data was collected in 2015
age = visit_year - demogra_data['birth_year']
demogra_data['age'] = age
age_diagnosis = demogra_data['diagnosis_year'].astype('int64') - demogra_data['birth_year']
demogra_data['age_diagnosis'] = age_diagnosis

# %%
demogra_data.dtypes
# Out:
# ROW_ID                            int64
# ROW_VERSION                       int64
# subject_id                       object
# cohort                           object
# gender                           object
# birth_year                        int64
# dominant_hand                    object
# upper_limb_length               float64
# upper_arm_length                  int64
# lower_arm_length                  int64
# lower_limb_length               float64
# thigh_length                      int64
# shank_length                      int64
# height                          float64
# weight                          float64
# visit_date                      float64
# diagnosis_day                   float64
# diagnosis_month                 float64
# diagnosis_year                   object
# pd_most_affected_side            object
# gait_impediments                 object
# posture_instability              object
# tremor                           object
# bradykinesia                     object
# disrupted_sleep                  object
# freeze_of_gait                   object
# dyskinesia                       object
# rigidity                         object
# other_symptoms                   object
# last_levodopa_dose_timestamp    float64
# regular_medication               object
# geneactive_num                    int64
# pebble_num                       object
# geneactive_hand                  object
# pebble_hand                      object
# smartphone_location              object
# recording_start                  object
# recording_end                    object
# timezone                         object
# updrs_time                       object
# updrs_score_p1                    int64
# updrs_score_p2                    int64
# updrs_score_p3                    int64
# updrs_score_p4                    int64
# h_and_y_score                   float64
# updrs_second_visit_time          object
# updrs_second_visit_score_p3       int64
# age                               int64
# age_diagnosis                     int64
# dtype: object

# %%
demogra_data.isnull().sum()
# Out:
# ROW_ID                           0
# ROW_VERSION                      0
# subject_id                       0
# cohort                           0
# gender                           0
# birth_year                       0
# dominant_hand                    0
# upper_limb_length               11
# upper_arm_length                 0
# lower_arm_length                 0
# lower_limb_length               11
# thigh_length                     0
# shank_length                     0
# height                           1
# weight                           1
# visit_date                       1
# diagnosis_day                   27
# diagnosis_month                 16
# diagnosis_year                   0
# pd_most_affected_side            0
# gait_impediments                 0
# posture_instability              0
# tremor                           0
# bradykinesia                     0
# disrupted_sleep                  0
# freeze_of_gait                   0
# dyskinesia                       0
# rigidity                         0
# other_symptoms                  11
# last_levodopa_dose_timestamp     1
# regular_medication              13
# geneactive_num                   0
# pebble_num                       9
# geneactive_hand                  0
# pebble_hand                      0
# smartphone_location             13
# recording_start                  0
# recording_end                    6
# timezone                         0
# updrs_time                       3
# updrs_score_p1                   0
# updrs_score_p2                   0
# updrs_score_p3                   0
# updrs_score_p4                   0
# h_and_y_score                    1
# updrs_second_visit_time          0
# updrs_second_visit_score_p3      0
# age                              0
# age_diagnosis                    0
# dtype: int64

# %%
demogra_data.describe()
# Out:
#           ROW_ID  ROW_VERSION   birth_year  upper_limb_length  \
# count  28.000000         28.0    28.000000          17.000000
# mean   14.500000          1.0  1952.500000          55.176471
# std     8.225975          0.0     8.962886           4.362271
# min     1.000000          1.0  1935.000000          49.000000
# 25%     7.750000          1.0  1946.500000          51.000000
# 50%    14.500000          1.0  1953.500000          55.000000
# 75%    21.250000          1.0  1959.000000          58.000000
# max    28.000000          1.0  1969.000000          64.000000
#
#        upper_arm_length  lower_arm_length  lower_limb_length  thigh_length  \
# count         28.000000         28.000000          17.000000     28.000000
# mean          31.607143         27.285714          90.441176     46.750000
# std            3.413907          2.992053           5.261542      7.346579
# min           25.000000         21.000000          81.000000     34.000000
# 25%           29.000000         25.000000          88.000000     40.000000
# 50%           31.500000         28.000000          90.000000     48.000000
# 75%           34.000000         29.000000          94.000000     53.000000
# max           40.000000         33.000000         102.000000     60.000000
#
#        shank_length      height  ...  last_levodopa_dose_timestamp  \
# count     28.000000   27.000000  ...                  2.700000e+01
# mean      42.321429  174.574074  ...                  1.431915e+09
# std        9.084189   11.612645  ...                  6.415554e+06
# min        4.000000  147.500000  ...                  1.423568e+09
# 25%       39.750000  166.500000  ...                  1.427204e+09
# 50%       42.500000  176.500000  ...                  1.430754e+09
# 75%       46.250000  181.650000  ...                  1.435013e+09
# max       58.000000  195.000000  ...                  1.445945e+09
#
#        geneactive_num  updrs_score_p1  updrs_score_p2  updrs_score_p3  \
# count       28.000000       28.000000       28.000000       28.000000
# mean     17826.678571       10.785714       13.571429       34.535714
# std       3137.802227        6.285534        5.245305       18.101529
# min       1816.000000        0.000000        1.000000        7.000000
# 25%      18415.000000        6.500000       10.000000       18.250000
# 50%      18416.000000       12.000000       14.000000       32.500000
# 75%      18425.000000       14.000000       16.000000       50.250000
# max      18426.000000       24.000000       23.000000       66.000000
#
#        updrs_score_p4  h_and_y_score  updrs_second_visit_score_p3        age  \
# count       28.000000      27.000000                    28.000000  28.000000
# mean         6.535714       2.259259                    40.857143  62.500000
# std          3.553633       0.594371                    17.721538   8.962886
# min          0.000000       2.000000                     6.000000  46.000000
# 25%          4.000000       2.000000                    30.000000  56.000000
# 50%          7.000000       2.000000                    40.500000  61.500000
# 75%          8.000000       2.000000                    53.000000  68.500000
# max         13.000000       4.000000                    76.000000  80.000000
#
#        age_diagnosis
# count      28.000000
# mean       53.392857
# std         9.765166
# min        35.000000
# 25%        46.750000
# 50%        53.000000
# 75%        58.750000
# max        74.000000
#
# [8 rows x 24 columns]

# %%
# Get age group
age_bound = np.arange(30,100,10)
age_group = np.empty((len(age),1))
age_group[:] = np.NaN
for i,item in enumerate(age_bound[:-1]):
    is_group = (item <= age) & (age < age_bound[i+1])
    age_group[is_group] = i
demogra_data['age_group'] = age_group
# Get age diagnosis group
age_diagnosis_group = np.empty((len(age_diagnosis),1))
age_diagnosis_group[:] = np.NaN
for i,item in enumerate(age_bound[:-1]):
    is_group = (item <= age_diagnosis) & (age_diagnosis < age_bound[i+1])
    age_diagnosis_group[is_group] = i
demogra_data['age_diagnosis_group'] = age_diagnosis_group

# %%
# Get updrs score group
score_bound = np.arange(0,100,20)
updrs_score_groups = ['updrs_score_p1', 'updrs_score_p2', 'updrs_score_p3', 'updrs_score_p4',
                     'updrs_second_visit_score_p3']
for i, group_name in enumerate(updrs_score_groups):
    updrs_score = demogra_data[group_name]
    new_group_name = group_name + '_group'
    score_group = np.empty((len(demogra_data),1))
    score_group[:] = np.NaN
    for j, bound in enumerate(score_bound[:-1]):
        is_group = (bound <= updrs_score) & (updrs_score < score_bound[j+1])
        score_group[is_group] = i
    demogra_data[new_group_name] = score_group

# %%
df_score
# Out:
#      subject_id  visit  session task_code  repetition tremor_GENEActivHand  \
# 0         3_BOS      1        1     stndg           1                    0
# 1         3_BOS      1        1     wlkgs           1                    0
# 2         3_BOS      1        1     wlkgc           1                    0
# 3         3_BOS      1        1     strsu           1                    0
# 4         3_BOS      1        1     strsd           1                    0
# ...         ...    ...      ...       ...         ...                  ...
# 6904     12_NYC      2        8     ntblt           1                    0
# 6905     12_NYC      2        8     drnkg           1                    0
# 6906     12_NYC      2        8     orgpa           1                    0
# 6907     12_NYC      2        8     fldng           1                    0
# 6908     12_NYC      2        8     sittg           1                    0
#
#      tremor_PebbleHand dyskinesia_GENEActivHand dyskinesia_PebbleHand  \
# 0                    0                      Yes                   Yes
# 1                    0                      Yes                   Yes
# 2                    0                      Yes                   Yes
# 3                    0                      Yes                    No
# 4                    0                       No                   Yes
# ...                ...                      ...                   ...
# 6904                 0                       No                    No
# 6905                 0                       No                    No
# 6906                 0                       No                    No
# 6907                 0                       No                    No
# 6908                 0                       No                    No
#
#      bradykinesia_GENEActivHand bradykinesia_PebbleHand
# 0                 NotApplicable           NotApplicable
# 1                            No                      No
# 2                            No                      No
# 3                            No                      No
# 4                            No                      No
# ...                         ...                     ...
# 6904              NotApplicable           NotApplicable
# 6905                         No                      No
# 6906                         No                      No
# 6907                         No                      No
# 6908                         No                      No
#
# [6909 rows x 11 columns]

# %%
# Get task group
# task categories
task_groups = [['stndg', 'sittg'],['wlkgs', 'wlkgc', 'wlkgp', 'strsu', 'strsd', 'ststd'],
               ['ftnr', 'ftnl', 'ramr', 'raml', 'drawg', 'typng', 'ntblt', 'drnkg', 'orgpa', 'fldng']]
task_group_names = ['no_voluntary_movement','lowerlimb_movement', 'upperlimb_movement']

# %%
df_score['task_group'] = np.NaN
for i,task in enumerate(task_groups):
    is_task = df_score['task_code'].isin(task).tolist()
    df_score['task_group'].loc[is_task] = i

# %%
df_meta = pd.DataFrame()
df_meta['subject_id'] = df_score['subject_id']
# select task data to be included in training models
feature_task = ['visit', 'session', 'task_code', 'task_group']
for ft in feature_task:
    df_meta[ft] = df_score[ft]

# %%
# select demographic data to be included in training models
feature_demogra = ['gender','age_group', 'age_diagnosis_group', 'dominant_hand', 'pd_most_affected_side',
                  'gait_impediments', 'posture_instability', 'tremor', 'bradykinesia', 'disrupted_sleep',
                  'freeze_of_gait', 'dyskinesia', 'rigidity', 'updrs_score_p1_group', 'updrs_score_p2_group',
                  'updrs_score_p3_group', 'updrs_score_p4_group', 'updrs_second_visit_score_p3_group']
subject_ids = df_meta.subject_id.unique()
for fd in feature_demogra:
    df_meta[fd] = np.nan
for fd in feature_demogra:
    for sb in subject_ids:
        feature = demogra_data[fd].loc[demogra_data['subject_id']==sb].values[0]
        df_meta[fd].loc[df_meta['subject_id']==sb] = feature

# %%
df_meta
# Out:
#      subject_id  visit  session task_code  task_group  gender  age_group  \
# 0         3_BOS      1        1     stndg         0.0  Female        5.0
# 1         3_BOS      1        1     wlkgs         1.0  Female        5.0
# 2         3_BOS      1        1     wlkgc         1.0  Female        5.0
# 3         3_BOS      1        1     strsu         1.0  Female        5.0
# 4         3_BOS      1        1     strsd         1.0  Female        5.0
# ...         ...    ...      ...       ...         ...     ...        ...
# 6904     12_NYC      2        8     ntblt         2.0    Male        4.0
# 6905     12_NYC      2        8     drnkg         2.0    Male        4.0
# 6906     12_NYC      2        8     orgpa         2.0    Male        4.0
# 6907     12_NYC      2        8     fldng         2.0    Male        4.0
# 6908     12_NYC      2        8     sittg         0.0    Male        4.0
#
#       age_diagnosis_group dominant_hand pd_most_affected_side  ...  \
# 0                     3.0         Right                 Right  ...
# 1                     3.0         Right                 Right  ...
# 2                     3.0         Right                 Right  ...
# 3                     3.0         Right                 Right  ...
# 4                     3.0         Right                 Right  ...
# ...                   ...           ...                   ...  ...
# 6904                  4.0         Right                  Left  ...
# 6905                  4.0         Right                  Left  ...
# 6906                  4.0         Right                  Left  ...
# 6907                  4.0         Right                  Left  ...
# 6908                  4.0         Right                  Left  ...
#
#      bradykinesia disrupted_sleep freeze_of_gait dyskinesia rigidity  \
# 0             Yes              No            Yes        Yes       No
# 1             Yes              No            Yes        Yes       No
# 2             Yes              No            Yes        Yes       No
# 3             Yes              No            Yes        Yes       No
# 4             Yes              No            Yes        Yes       No
# ...           ...             ...            ...        ...      ...
# 6904          Yes              No             No        Yes      Yes
# 6905          Yes              No             No        Yes      Yes
# 6906          Yes              No             No        Yes      Yes
# 6907          Yes              No             No        Yes      Yes
# 6908          Yes              No             No        Yes      Yes
#
#      updrs_score_p1_group updrs_score_p2_group updrs_score_p3_group  \
# 0                     0.0                  1.0                  2.0
# 1                     0.0                  1.0                  2.0
# 2                     0.0                  1.0                  2.0
# 3                     0.0                  1.0                  2.0
# 4                     0.0                  1.0                  2.0
# ...                   ...                  ...                  ...
# 6904                  0.0                  1.0                  2.0
# 6905                  0.0                  1.0                  2.0
# 6906                  0.0                  1.0                  2.0
# 6907                  0.0                  1.0                  2.0
# 6908                  0.0                  1.0                  2.0
#
#       updrs_score_p4_group  updrs_second_visit_score_p3_group
# 0                      3.0                                4.0
# 1                      3.0                                4.0
# 2                      3.0                                4.0
# 3                      3.0                                4.0
# 4                      3.0                                4.0
# ...                    ...                                ...
# 6904                   3.0                                4.0
# 6905                   3.0                                4.0
# 6906                   3.0                                4.0
# 6907                   3.0                                4.0
# 6908                   3.0                                4.0
#
# [6909 rows x 23 columns]

# %%
# save metadata features
save_file_path = os.path.join(save_path, 'metadata_features.pkl')
df_meta.to_pickle(save_file_path)
